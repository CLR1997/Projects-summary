# %%
import pickle

# Load the pickle file
with open('/Users/colinlinke/Documents/AI in Industry Project/AI_Industry_Project.nosync/benchmarks/synthetic/preprocess/properties.pkl', 'rb') as f:
    properties = pickle.load(f)

# Display the contents
for task, data in properties.items():
    print(f"\nTask: {task}")
    print(data)
# Out:
# Task: (2, 'hard')
# [((8, 6), 1.78704702e-01, 1.13509330e+02)
#  ((13, 24), 1.09922762e-01, 2.50276847e+02)
#  ((19, 24), 2.05820336e-01, 6.90171363e+02)
#  ((29, 24), 6.49022566e-02, 1.02295419e+02)
#  ((8, 38), 1.30155349e-01, 1.95727587e+02)
#  ((8, 55), 1.16824733e-01, 2.65840296e+02)
#  ((13, 37), 3.25747029e-02, 1.00252570e+02)
#  ((19, 37), 3.52919732e-01, 5.06919486e+02)
#  ((29, 37), 8.80780281e-02, 6.59407824e+01)
#  ((39, 6), 3.00617612e-03, 2.05571274e+01)
#  ((39, 14), 8.57570394e-02, 5.57040608e+01)
#  ((40, 6), 2.64833080e-01, 2.33257435e+02)
#  ((40, 24), 2.05000103e-01, 6.75639517e+02)
#  ((47, 24), 3.00766751e-05, 5.15296517e-01)
#  ((48, 6), 2.49360018e-02, 1.47849958e+00)]
#
# Task: (4, 'hard')
# [((5, 0), 0.05988099,  35.50747297) ((5, 1), 0.01837165,  36.16121673)
#  ((5, 2), 0.10750356,  15.43316996) ((5, 3), 0.04178101,  34.33980274)
#  ((5, 4), 0.04498843,  83.76959422) ((5, 5), 0.04501855,  39.78353961)
# ...
